# %% [markdown]
# <a href="https://colab.research.google.com/github/Christiancardenas-code/Python/blob/main/PY_CCQ_A05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.- Programa en Python que genere 40 números aleatorios entre el 0 y 200, desplegar los números y la leyenda de cada número si es par o impar , la cantidad de los números pares e impares así como la suma de los números pares o impares.

# %%
import random
i = 1
par = 0
impar = 0

def numeros():
  i = 1
  par = 0
  impar = 0

  for i in range(0, 40, 1):
    num = random.randint(0, 200)

    if num % 2 == 0:
      print(f"El numero {num} es par")
      par = par + 1


    else:
      print(f"El numero {num} es impar")
      impar = impar + 1

  print("---------------------------")
  print(f"Numero de pares: {par}")
  print(f"Numero de impares: {impar}")

numeros()

# %% [markdown]
# 2.- Programa en Python que despliegue la tabla de multiplicar de un número dado (número entre el 1 y 20).

# %%
try:
  tabla = int(input("Dame un numero: "))

  def tablas():

    if tabla >= 1 and tabla <= 20:

      for i in range(1 , 11, 1):
        
        multi = tabla * i
        print(f"{tabla} * {i} = {multi}")

    else:
      print("\nIntroduce un numero entre el 1 y el 20")

except ValueError:
  print("\nIntroduce un numero entre el 1 y el 20")

else:
  tablas()

# %% [markdown]
# 3.- Programa en Python que lea una calificación, las calificación deberá estar en el rango de 0 a 100, si hay un error de captura, mostrar mensaje de error. con la calificación correcta mostrar msg de aprobado reprobado.

# %%
try:
  cantidad = int(input("Cuantas calificaciones? "))

  def prom():
    
    for i in range(0, cantidad, 1):

      try:

        cal = int(input(f"\nCalifiacion {i+1}: "))

        if cal > 100:
          print("Error")
        
        elif cal >= 60:
          print("Aprobado")
        
        else:
          print("Reprobado")

      except:
        print("\nError, introduce un valor correcto")

except:
  print("\nError, introduce un valor correcto")

else:
  prom()

# %% [markdown]
# 4.- Programa en Python que lea n cantidad de números enteros dentro de un rango dado (> 0 ) , el programa deberá terminar cuando el usuario introduzca el número cero. Desplegar la suma de números y la media.

# %%
suma = 0
media = 0
i = 1

def valores():
  suma = 0
  media = 0
  i = 1

  while i > 0:
        
    try:
      num = int(input("Dame un numero: "))

      suma = suma + num

      if num == 0:
        i = 0

      else:
        i = i + 1

        media = media + 1

        num = 0

    except:
      print("Introduce un valor correcto")

      prom = suma / media

valores()

print(f"\nSuma: {suma}")
print(f"Media: {prom}")

# %% [markdown]
# 5.- Programa en Python que sirva para leer el promedio de una materia. donde el usuario tendrá un máximo de 3 oportunidades de cursar la materia, si el promedio es aprobado, felicitarlo y continuar el siguiente semestre, si promedio es reprobado deberá salir mensaje de repetir materia o es baja académica si ha reprobado 3 veces.

# %%
def promedios():
  i = 1
  prom = 0
  re = 0
  band = True

  while band:
    while i <= 3:

      cal = int(input(f"Oportunidad {re+1}, calificacion {i}: "))

      prom = prom + cal
      i = i + 1

    prom = prom / 3

    if prom >= 60:
      print("\nAprobado")
      break

    else:
      print("\nRecursando")

      re = re + 1
      i = 1
      prom = 0

    if re >= 3:
      print("\nBaja academica")
      band = False

promedios()

# %% [markdown]
# 6.- función que lea n cantidad de números hasta que el usuario lo desee, desplegar la suma de los números, media y valor de los números mayores y menores.

# %%
def menu():

  print("-----------------Menu-----------------")
  print("1. Cantidad de numeros")
  print("2. Pares e impares")
  print("3. Validar un numero por el usuario")
  print("4. Area de un triangulo")
  print("5. Validar un numero")
  print("6. Promedios")
  print("0. Salir")
  print("--------------------------------------")

  op = int(input("Escoge una opcion: "))

  while op != 0:
    if op == 1:
      print("\n")
      suma()
      break

    if op == 2:
      print("\n")
      paresimpares()
      break

    if op == 3:
      print("\n")
      rangos()
      break

    if op == 4:
      print("\n")
      triangulo()
      break
    
    if op == 5:
      print("\n")
      validar()
      break

    if op == 6:
      print("\n")
      uabc()
      break
################################################################################
def suma(total = 0, band = True, media = 0, i = 1, menor = 1000, mayor = 0):

  while band:

    num = int(input("Dame un numero: "))
    total = total + num

    print(f"La suma es: {total}")

    if num >= mayor:
      mayor = num
    
    if num < menor:
      menor = num

    op = int(input("Continuar? 1. Si | 0. No\n"))

    if op == 0:
      band = False

  i = i + 1

  media = total / i

  print(f"\nLa media es: {media}")
  print(f"El mayor es: {mayor}")
  print(f"El menor es: {menor}")
################################################################################
def paresimpares(par = 0, impar = 0, i = 1, num = 0):
  import random

  while i < 15:

    num = random.randint(10, 60)

    if num % 2 == 0:
      print(f"El numero {num} es par")
      par = par + 1

    else:
      print(f"El numero {num} es impar")
      impar = impar + 1

      i = i + 1

  print(f"\nTotal de pares: {par}")
  print(f"Total de impares: {impar}")
################################################################################
def rangos(total = 0, band = True, media = 0, i = 1):
  
  ri = int(input("Rango inicial: "))
  rf = int(input("Rango final: "))
  print("\n")

  while band:

    num = int(input("Dame un numero dentro del rango: "))

    if num >= ri and num <= rf:
      total = total + num

      print(f"Esta dentro del rango: {num}")

    else:
      print(f"Esta fuera del rango: {num}")
      break

    op = int(input("Continuar? 1. Si | 0. No\n"))

    if op == 0:
      band = False

    i = i + 1
  
  media = total / i

  print(f"\nLa media es: {media}")
################################################################################
def triangulo( area = 0):

  base = int(input("Dame la base: "))
  alt = int(input("Dame la altura: "))

  area = (base * alt) / 2

  print(f"El area es: {area}")
################################################################################
def validar (band = True, i = 1, num = 0):

  ri = int(input("Rango inicial: "))
  rf = int(input("Rango final: "))

  while band:

    num = int(input("Dame un numero dentro del rango: "))

    if num >= ri and num <= rf:
      total = total + num

      print(f"Esta dentro del rango: {total}")

    else:
      print(f"Esta fuera del rango: {total}")
      break
    
    op = int(input("Continuar? 1. Si | 0. No\n"))

    if op == 0:
      band = False
    
    i = i + 1
################################################################################
def uabc(band = True, i = 1, prom = 0, re = 0):

  while band:
    while i <= 3:

      cal = int(input(f"Oportunidad {re}, calificacion {re}: "))

      prom = prom + cal
      i = i + 1
      prom = prom / 3

      if prom > 60:
        print("Aprobado\n")
        break

      else:
        print("Recursar\n")

        re = re + 1
        i = 1
        prom = 0

      if re >= 3:
        print("Baja academica")

        band = False
################################################################################
menu()
