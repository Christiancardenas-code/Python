# %% [markdown]
# <a href="https://colab.research.google.com/github/Christiancardenas-code/Python/blob/main/Ejercicio%20de%20examen%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate

diccionario = {"Matricula" : "", "Edad" : "", "Nombre" : "",
               "Ap paterno" : "", "Ap materno" : "", "Sexo" : ""}

datos = []

def manual():
  i = 1

  while i <= 1:
    try:
      gender = int(input("1. Hombre | 2. Mujer\n"))
      paterno = str(input("Apellido paterno: "))
      materno = str(input("Apellido materno: "))
      nombre = str(input("Nombre(s): "))
      age = int(input("Edad: "))
      matricula = int(input("Matricula: "))

    except:
      print("\n-Error, vuelve a intentarlo-\n")

    else:

      if gender == 1:
        sex = "Hombre"

      else:
        sex = "Mujer"

      datos.append({"Matricula" : matricula, "Edad" : age, "Nombre" : nombre,
                    "Ap paterno" : paterno, "Ap materno" : materno, "Sexo" : sex})
      
      i = i + 1

def impresion():
  print("----------------------------------------------------------------------")
  print("Matricula" " " "Edad" " " "Nombre" " " "Ap paterno" " " "Ap materno" " " "Sexo" " " "\n")
  print(tabulate(datos))

def menu():
  while(True):
    print("--------------------Menu--------------------")
    print("1. Agregar datos")
    print("2. Imprimir")
    print("0. Salir")

    print("--------------------------------------------")
    try:
      op = int(input("Escoge una opcion: "))

    except:
      print("\n-Error, vuelve a intentarlo-\n")

    else:

      if op == 1:
        print("\n")
        manual()

      if op == 2:
        print("\n")
        impresion()

      if op == 0:
        break

menu()
# Out:
# --------------------Menu--------------------
# 1. Agregar datos
# 2. Imprimir
# 0. Salir
# --------------------------------------------
# Escoge una opcion: 1
#
#
# 1. Hombre | 2. Mujer
# 1
# Apellido paterno: cardenas
# Apellido materno: quiroz
# Nombre(s): christian
# Edad: 21
# Matricula: 369196
# --------------------Menu--------------------
# 1. Agregar datos
# 2. Imprimir
# 0. Salir
# --------------------------------------------
# Escoge una opcion: 2
#
#
# ----------------------------------------------------------------------
# Matricula Edad Nombre Ap paterno Ap materno Sexo
#
# ------  --  ---------  --------  ------  ------
# 369196  21  christian  cardenas  quiroz  Hombre
# ------  --  ---------  --------  ------  ------
# --------------------Menu--------------------
# 1. Agregar datos
# 2. Imprimir
# 0. Salir
# --------------------------------------------
# Escoge una opcion: a
#
# -Error, vuelve a intentarlo-
#
# --------------------Menu--------------------
# 1. Agregar datos
# 2. Imprimir
# 0. Salir
# --------------------------------------------
# Escoge una opcion: 0
